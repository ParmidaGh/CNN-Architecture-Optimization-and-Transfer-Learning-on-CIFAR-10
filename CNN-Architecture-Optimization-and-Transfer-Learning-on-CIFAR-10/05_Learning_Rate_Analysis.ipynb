# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %% [markdown]
# ## **0.0001**

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.0001
model_name='ث-0.0001'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, bias=True)
        self.batch_norm3 = nn.BatchNorm2d(64)
        self.pool3 = nn.MaxPool2d(2, stride=2)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, bias=True)
        self.batch_norm4 = nn.BatchNorm2d(64)
        self.pool4 = nn.MaxPool2d(2, stride=1)

        # Classification layers
        self.fc1 = nn.Linear(64 * 1 * 1, 256)
        self.dropout = nn.Dropout(p=0.3)  # Dropout layer
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.batch_norm1(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.batch_norm2(x)
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.batch_norm3(x)
        x = self.pool3(x)
        x = F.relu(self.conv4(x))
        x = self.batch_norm4(x)
        x = self.pool4(x)
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Apply dropout
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 25 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    #check stop condition
    last_3_acc = accuracy_list_valid[-3:]
    if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
        stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 47075891.90it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 48.5000, valid loss: 51.5000
# train accuracy: 50.5333, train loss: 49.4667
#
#
# Report for epoch: 2
# valid accuracy: 54.4400, valid loss: 45.5600
# train accuracy: 57.4356, train loss: 42.5644
#
#
# Report for epoch: 3
# valid accuracy: 58.8400, valid loss: 41.1600
# train accuracy: 62.0000, train loss: 38.0000
#
#
# Report for epoch: 4
# valid accuracy: 61.2000, valid loss: 38.8000
# train accuracy: 65.4578, train loss: 34.5422
#
#
# Report for epoch: 5
# valid accuracy: 62.3000, valid loss: 37.7000
# train accuracy: 67.8622, train loss: 32.1378
#
#
# Report for epoch: 6
# valid accuracy: 63.5400, valid loss: 36.4600
# train accuracy: 70.1000, train loss: 29.9000
#
#
# Report for epoch: 7
# valid accuracy: 64.9800, valid loss: 35.0200
# train accuracy: 71.8600, train loss: 28.1400
#
#
# Report for epoch: 8
# valid accuracy: 65.2000, valid loss: 34.8000
# train accuracy: 73.8000, train loss: 26.2000
#
#
# Report for epoch: 9
# valid accuracy: 65.2400, valid loss: 34.7600
# train accuracy: 74.6289, train loss: 25.3711
#
# ================================
#
# (Training finished in 9 epochs)
# Average epoch's runtime: 36.22887637880113 seconds
# accuracy on test data: 64.5800, loss of test data: 35.6700

# %% [markdown]
# ## **0.01**

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.01
model_name='ث-0.01'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, bias=True)
        self.batch_norm3 = nn.BatchNorm2d(64)
        self.pool3 = nn.MaxPool2d(2, stride=2)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, bias=True)
        self.batch_norm4 = nn.BatchNorm2d(64)
        self.pool4 = nn.MaxPool2d(2, stride=1)

        # Classification layers
        self.fc1 = nn.Linear(64 * 1 * 1, 256)
        self.dropout = nn.Dropout(p=0.3)  # Dropout layer
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.batch_norm1(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.batch_norm2(x)
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.batch_norm3(x)
        x = self.pool3(x)
        x = F.relu(self.conv4(x))
        x = self.batch_norm4(x)
        x = self.pool4(x)
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Apply dropout
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 25 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    #check stop condition
    last_3_acc = accuracy_list_valid[-3:]
    if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
        stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 52.0400, valid loss: 47.9600
# train accuracy: 53.5133, train loss: 46.4867
#
#
# Report for epoch: 2
# valid accuracy: 60.1400, valid loss: 39.8600
# train accuracy: 62.4222, train loss: 37.5778
#
#
# Report for epoch: 3
# valid accuracy: 63.8200, valid loss: 36.1800
# train accuracy: 66.9222, train loss: 33.0778
#
#
# Report for epoch: 4
# valid accuracy: 64.5200, valid loss: 35.4800
# train accuracy: 68.4844, train loss: 31.5156
#
#
# Report for epoch: 5
# valid accuracy: 65.1000, valid loss: 34.9000
# train accuracy: 69.7244, train loss: 30.2756
#
#
# Report for epoch: 6
# valid accuracy: 65.3200, valid loss: 34.6800
# train accuracy: 69.6667, train loss: 30.3333
#
#
# Report for epoch: 7
# valid accuracy: 67.5600, valid loss: 32.4400
# train accuracy: 73.8867, train loss: 26.1133
#
#
# Report for epoch: 8
# valid accuracy: 68.9000, valid loss: 31.1000
# train accuracy: 75.0222, train loss: 24.9778
#
#
# Report for epoch: 9
# valid accuracy: 68.5800, valid loss: 31.4200
# train accuracy: 75.3422, train loss: 24.6578
#
#
# Report for epoch: 10
# valid accuracy: 69.0200, valid loss: 30.9800
# train accuracy: 76.8844, train loss: 23.1156
#
# ================================
#
# (Training finished in 10 epochs)
# Average epoch's runtime: 36.913853883743286 seconds
# accuracy on test data: 70.1600, loss of test data: 29.5500

# %% [markdown]
# ## **0.1**

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.1
model_name='ث-0.1'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, bias=True)
        self.batch_norm3 = nn.BatchNorm2d(64)
        self.pool3 = nn.MaxPool2d(2, stride=2)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, bias=True)
        self.batch_norm4 = nn.BatchNorm2d(64)
        self.pool4 = nn.MaxPool2d(2, stride=1)

        # Classification layers
        self.fc1 = nn.Linear(64 * 1 * 1, 256)
        self.dropout = nn.Dropout(p=0.3)  # Dropout layer
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.batch_norm1(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.batch_norm2(x)
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.batch_norm3(x)
        x = self.pool3(x)
        x = F.relu(self.conv4(x))
        x = self.batch_norm4(x)
        x = self.pool4(x)
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Apply dropout
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 25 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    #check stop condition
    last_3_acc = accuracy_list_valid[-3:]
    if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
        stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 9.3400, valid loss: 90.6600
# train accuracy: 10.0733, train loss: 89.9267
#
#
# Report for epoch: 2
# valid accuracy: 9.6800, valid loss: 90.3200
# train accuracy: 10.0356, train loss: 89.9644
#
#
# Report for epoch: 3
# valid accuracy: 9.3400, valid loss: 90.6600
# train accuracy: 10.0733, train loss: 89.9267
#
# ================================
#
# (Training finished in 3 epochs)
# Average epoch's runtime: 36.10420823097229 seconds
# accuracy on test data: 10.0000, loss of test data: 90.0000

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.1
model_name='ث-0.1'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, bias=True)
        self.batch_norm2 = nn.BatchNorm2d(32)
        self.pool2 = nn.MaxPool2d(2, stride=2)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, bias=True)
        self.batch_norm3 = nn.BatchNorm2d(64)
        self.pool3 = nn.MaxPool2d(2, stride=2)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, bias=True)
        self.batch_norm4 = nn.BatchNorm2d(64)
        self.pool4 = nn.MaxPool2d(2, stride=1)

        # Classification layers
        self.fc1 = nn.Linear(64 * 1 * 1, 256)
        self.dropout = nn.Dropout(p=0.3)  # Dropout layer
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.batch_norm1(x)
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.batch_norm2(x)
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.batch_norm3(x)
        x = self.pool3(x)
        x = F.relu(self.conv4(x))
        x = self.batch_norm4(x)
        x = self.pool4(x)
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Apply dropout
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 10 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    # #check stop condition
    # last_3_acc = accuracy_list_valid[-3:]
    # if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
    #     stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 8.9200, valid loss: 91.0800
# train accuracy: 10.1200, train loss: 89.8800
#
#
# Report for epoch: 2
# valid accuracy: 10.4400, valid loss: 89.5600
# train accuracy: 9.9511, train loss: 90.0489
#
#
# Report for epoch: 3
# valid accuracy: 10.1000, valid loss: 89.9000
# train accuracy: 9.9889, train loss: 90.0111
#
#
# Report for epoch: 4
# valid accuracy: 10.1000, valid loss: 89.9000
# train accuracy: 9.9889, train loss: 90.0111
#
#
# Report for epoch: 5
# valid accuracy: 10.4400, valid loss: 89.5600
# train accuracy: 9.9511, train loss: 90.0489
#
#
# Report for epoch: 6
# valid accuracy: 10.1000, valid loss: 89.9000
# train accuracy: 9.9889, train loss: 90.0111
#
#
# Report for epoch: 7
# valid accuracy: 10.1000, valid loss: 89.9000
# train accuracy: 9.9889, train loss: 90.0111
#
#
# Report for epoch: 8
# valid accuracy: 8.9200, valid loss: 91.0800
# train accuracy: 10.1200, train loss: 89.8800
#
#
# Report for epoch: 9
# valid accuracy: 10.4400, valid loss: 89.5600
# train accuracy: 9.9511, train loss: 90.0489
#
#
# Report for epoch: 10
# valid accuracy: 9.8400, valid loss: 90.1600
# train accuracy: 10.0178, train loss: 89.9822
#
# ================================
#
# (Training finished in 10 epochs)
# Average epoch's runtime: 36.57616930007934 seconds
# accuracy on test data: 10.0000, loss of test data: 90.0000
