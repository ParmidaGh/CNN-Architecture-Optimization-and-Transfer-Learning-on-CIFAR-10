# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %% [markdown]
# ## **Without** early stopping

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.001
model_name='Basic'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])


trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=4, bias=True)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=4, bias=True)
        self.pool2 = nn.MaxPool2d(2, stride=2)

        # Classification layers
        self.fc1 = nn.Linear(32 * 5 * 5, 256)
        self.fc2 = nn.Linear(256, 10)


    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 25 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    # #check stop condition
    # last_3_acc = accuracy_list_valid[-3:]
    # if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
    #     stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 49059684.04it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 56.6200, valid loss: 43.3800
# train accuracy: 58.3622, train loss: 41.6378
#
#
# Report for epoch: 2
# valid accuracy: 63.3400, valid loss: 36.6600
# train accuracy: 67.0067, train loss: 32.9933
#
#
# Report for epoch: 3
# valid accuracy: 66.6200, valid loss: 33.3800
# train accuracy: 72.3578, train loss: 27.6422
#
#
# Report for epoch: 4
# valid accuracy: 65.4600, valid loss: 34.5400
# train accuracy: 72.4289, train loss: 27.5711
#
#
# Report for epoch: 5
# valid accuracy: 69.1400, valid loss: 30.8600
# train accuracy: 79.1444, train loss: 20.8556
#
#
# Report for epoch: 6
# valid accuracy: 69.9200, valid loss: 30.0800
# train accuracy: 81.8622, train loss: 18.1378
#
#
# Report for epoch: 7
# valid accuracy: 70.0000, valid loss: 30.0000
# train accuracy: 83.3733, train loss: 16.6267
#
#
# Report for epoch: 8
# valid accuracy: 68.5800, valid loss: 31.4200
# train accuracy: 84.7067, train loss: 15.2933
#
#
# Report for epoch: 9
# valid accuracy: 69.0000, valid loss: 31.0000
# train accuracy: 87.2467, train loss: 12.7533
#
#
# Report for epoch: 10
# valid accuracy: 68.6200, valid loss: 31.3800
# train accuracy: 88.5222, train loss: 11.4778
#
#
# Report for epoch: 11
# valid accuracy: 66.6200, valid loss: 33.3800
# train accuracy: 87.5667, train loss: 12.4333
#
#
# Report for epoch: 12
# valid accuracy: 68.4600, valid loss: 31.5400
# train accuracy: 91.9889, train loss: 8.0111
#
#
# Report for epoch: 13
# valid accuracy: 67.7200, valid loss: 32.2800
# train accuracy: 92.6178, train loss: 7.3822
#
#
# Report for epoch: 14
# valid accuracy: 68.5000, valid loss: 31.5000
# train accuracy: 94.3844, train loss: 5.6156
#
#
# Report for epoch: 15
# valid accuracy: 66.3400, valid loss: 33.6600
# train accuracy: 92.7844, train loss: 7.2156
#
#
# Report for epoch: 16
# valid accuracy: 67.4000, valid loss: 32.6000
# train accuracy: 93.0778, train loss: 6.9222
#
#
# Report for epoch: 17
# valid accuracy: 67.6800, valid loss: 32.3200
# train accuracy: 95.7733, train loss: 4.2267
#
#
# Report for epoch: 18
# valid accuracy: 67.5400, valid loss: 32.4600
# train accuracy: 94.8556, train loss: 5.1444
#
#
# Report for epoch: 19
# valid accuracy: 67.0200, valid loss: 32.9800
# train accuracy: 94.2556, train loss: 5.7444
#
#
# Report for epoch: 20
# valid accuracy: 66.9200, valid loss: 33.0800
# train accuracy: 95.4978, train loss: 4.5022
#
#
# Report for epoch: 21
# valid accuracy: 66.6200, valid loss: 33.3800
# train accuracy: 95.6067, train loss: 4.3933
#
#
# Report for epoch: 22
# valid accuracy: 67.2600, valid loss: 32.7400
# train accuracy: 96.2133, train loss: 3.7867
#
#
# Report for epoch: 23
# valid accuracy: 66.7400, valid loss: 33.2600
# train accuracy: 96.1733, train loss: 3.8267
#
#
# Report for epoch: 24
# valid accuracy: 67.1400, valid loss: 32.8600
# train accuracy: 97.1044, train loss: 2.8956
#
#
# Report for epoch: 25
# valid accuracy: 66.5600, valid loss: 33.4400
# train accuracy: 95.7533, train loss: 4.2467
#
# ================================
#
# (Training finished in 25 epochs)
# Average epoch's runtime: 31.637738666534425 seconds
# accuracy on test data: 66.8600, loss of test data: 33.1400

# %% [markdown]
# ## **With** early stopping

# %%
from torch.nn.modules.dropout import Dropout
#مقدار دهی اولیه
batch_size = 32
learning_rate=0.001
model_name='Basic'



import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import os
import time


# محاسبه دقت
def calculate_accuracy(dataloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.cuda(), labels.cuda()
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = round(100 * correct / total, 4)  # اعشار 4 رقمی
    return accuracy


#ساخت Loader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # نرمال سازی
])


trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)

#یک پنجم دیتا آموزش به صورت تصادفی به عنوان دیتا valid
trainset, validset = random_split(trainset,[45000,5000])
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2,pin_memory=True)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size,
                                          shuffle=False, num_workers=2,pin_memory=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2,pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


import torch.nn as nn
import torch.nn.functional as F


class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=4, bias=True)
        self.pool1 = nn.MaxPool2d(2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=4, bias=True)
        self.pool2 = nn.MaxPool2d(2, stride=2)

        # Classification layers
        self.fc1 = nn.Linear(32 * 5 * 5, 256)
        self.fc2 = nn.Linear(256, 10)


    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

net = Network()
if torch.cuda.is_available():
  net = net.to(torch.device("cuda:0"))



import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)


epoch=0
stop_condition=False

accuracy_list_valid=[]
error_list_train_plot=[]
error_list_valid_plot=[]


#Training part
start_time = time.time()
while (epoch < 20 and not stop_condition):
    for i, data in enumerate(trainloader, 0):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.cuda(), labels.cuda()

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        #print(outputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    epoch+=1


    accuracy_valid=calculate_accuracy(validloader)
    accuracy_train=calculate_accuracy(trainloader)
    print(f'\nReport for epoch: {epoch}')
    print(f'valid accuracy: {accuracy_valid:.4f}, valid loss: {100-accuracy_valid:.4f}')
    print(f'train accuracy: {accuracy_train:.4f}, train loss: {100-accuracy_train:.4f}\n')


    error_list_valid_plot.append(100-accuracy_valid)
    error_list_train_plot.append(100-accuracy_train)
    accuracy_list_valid.append(accuracy_valid)

    #check stop condition
    last_3_acc = accuracy_list_valid[-3:]
    if max(last_3_acc) - sum(last_3_acc) / 3 <= 0.3:
        stop_condition = True
end_time = time.time()



#Report generating
avg_epoch_runtime=(end_time-start_time)/epoch

print("================================\n")
print(f"(Training finished in {epoch} epochs)")
print(f"Average epoch's runtime: {avg_epoch_runtime} seconds")
print(f'accuracy on test data: {calculate_accuracy(testloader):.4f}, loss of test data: {100-calculate_accuracy(testloader):.4f}\n\n')


if (os.path.exists('/content/drive/MyDrive/model')==False):
  os.mkdir('/content/drive/MyDrive/model')
PATH = '/content/drive/MyDrive/model/'+model_name+'.pth'
torch.save(net.state_dict(), PATH)


dataiter = iter(testloader)
images, labels = next(dataiter)


#load model
net = Network()
net.load_state_dict(torch.load(PATH))


#Drawing plot
import numpy as np
import matplotlib.pyplot as plt

x=list(range(1,len(error_list_train_plot)+1))

x=np.array(x)
y_train=np.array(error_list_train_plot)
y_valid=np.array(error_list_valid_plot)

plt.plot(x,y_train)
plt.plot(x,y_valid)
plt.xlabel("epoch")
plt.ylabel('loss')
plt.legend(['train loss', 'valid loss'])
plt.savefig('/content/drive/MyDrive/model/'+model_name+'.png')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# Report for epoch: 1
# valid accuracy: 53.5600, valid loss: 46.4400
# train accuracy: 54.5022, train loss: 45.4978
#
#
# Report for epoch: 2
# valid accuracy: 58.5400, valid loss: 41.4600
# train accuracy: 61.8244, train loss: 38.1756
#
#
# Report for epoch: 3
# valid accuracy: 64.1600, valid loss: 35.8400
# train accuracy: 68.6178, train loss: 31.3822
#
#
# Report for epoch: 4
# valid accuracy: 66.4800, valid loss: 33.5200
# train accuracy: 72.5267, train loss: 27.4733
#
#
# Report for epoch: 5
# valid accuracy: 67.4200, valid loss: 32.5800
# train accuracy: 74.7356, train loss: 25.2644
#
#
# Report for epoch: 6
# valid accuracy: 67.9600, valid loss: 32.0400
# train accuracy: 76.8156, train loss: 23.1844
#
#
# Report for epoch: 7
# valid accuracy: 66.7600, valid loss: 33.2400
# train accuracy: 76.0822, train loss: 23.9178
#
#
# Report for epoch: 8
# valid accuracy: 68.5800, valid loss: 31.4200
# train accuracy: 79.9067, train loss: 20.0933
#
#
# Report for epoch: 9
# valid accuracy: 68.9800, valid loss: 31.0200
# train accuracy: 81.8756, train loss: 18.1244
#
#
# Report for epoch: 10
# valid accuracy: 67.5800, valid loss: 32.4200
# train accuracy: 81.2533, train loss: 18.7467
#
#
# Report for epoch: 11
# valid accuracy: 67.3200, valid loss: 32.6800
# train accuracy: 82.4178, train loss: 17.5822
#
#
# Report for epoch: 12
# valid accuracy: 67.5600, valid loss: 32.4400
# train accuracy: 83.8156, train loss: 16.1844
#
# ================================
#
# (Training finished in 12 epochs)
# Average epoch's runtime: 31.299010674158733 seconds
# accuracy on test data: 67.5700, loss of test data: 32.4300
